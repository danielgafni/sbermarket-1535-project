# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Загрузка данных с диска

# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")  # файл train.csv должен лежать в директории, где запущен ноутбук

# %% [markdown]
# Посмотрим на первые несколько строк:

# %%
data.head()
# Out:
#       week  competitors_spendings  seasonality  fb_page_daily_viral_reach  \
# 0  2019-01             12849226.0     1.008971                       2219
# 1  2019-02             12849226.0     0.745846                       1841
# 2  2019-03             12849226.0     0.852687                       3103
# 3  2019-04             12849226.0     1.067596                       1838
# 4  2019-05             12849226.0     1.127907                       1541
#
#    holidays_  sms_resips  email  pandemia_search  vk_reach  price_ratio_  \
# 0        6.0         0.0      0              NaN      1965      1.499212
# 1        2.0         0.0      0              NaN      1772      1.576162
# 2        0.0         0.0      0              NaN      1862      1.578232
# 3        0.0         0.0      0              NaN     44102      1.579293
# 4        0.0         0.0      0              NaN     93440      1.552700
#
#    pr_coverage  app_clicks  ots  fb_page_daily_paid_reach  push  \
# 0          NaN        1098  NaN                  484530.0   0.0
# 1          NaN        2025  NaN                  523417.0   0.0
# 2          NaN        2921  NaN                   28250.0   0.0
# 3          NaN       19691  NaN                  238273.0   0.0
# 4          NaN       10472  NaN                  101968.0   0.0
#
#    price_index_macroeconomics  price_index_sbermarket  rebranding_contin  \
# 0                      101.36              151.960146                  0
# 1                      101.36              159.759803                  0
# 2                      101.36              159.969601                  0
# 3                      101.36              160.077088                  0
# 4                      100.89              156.651941                  0
#
#    order_app
# 0     7620.6
# 1     6505.2
# 2     7764.9
# 3     9254.7
# 4     9133.8

# %% [markdown]
# Приведем колонку с неделями к специальному типу `date`, чтобы с ней можно было легко работать в дальнейшем (лайфхак [отсюда](https://stackoverflow.com/questions/17087314/get-date-from-week-number)):

# %%
data["week"] = pd.to_datetime(data["week"] + "-1", format="%Y-%W-%w")

# %%
data.head()
# Out:
#         week  competitors_spendings  seasonality  fb_page_daily_viral_reach  \
# 0 2019-01-07             12849226.0     1.008971                       2219
# 1 2019-01-14             12849226.0     0.745846                       1841
# 2 2019-01-21             12849226.0     0.852687                       3103
# 3 2019-01-28             12849226.0     1.067596                       1838
# 4 2019-02-04             12849226.0     1.127907                       1541
#
#    holidays_  sms_resips  email  pandemia_search  vk_reach  price_ratio_  \
# 0        6.0         0.0      0              NaN      1965      1.499212
# 1        2.0         0.0      0              NaN      1772      1.576162
# 2        0.0         0.0      0              NaN      1862      1.578232
# 3        0.0         0.0      0              NaN     44102      1.579293
# 4        0.0         0.0      0              NaN     93440      1.552700
#
#    pr_coverage  app_clicks  ots  fb_page_daily_paid_reach  push  \
# 0          NaN        1098  NaN                  484530.0   0.0
# 1          NaN        2025  NaN                  523417.0   0.0
# 2          NaN        2921  NaN                   28250.0   0.0
# 3          NaN       19691  NaN                  238273.0   0.0
# 4          NaN       10472  NaN                  101968.0   0.0
#
#    price_index_macroeconomics  price_index_sbermarket  rebranding_contin  \
# 0                      101.36              151.960146                  0
# 1                      101.36              159.759803                  0
# 2                      101.36              159.969601                  0
# 3                      101.36              160.077088                  0
# 4                      100.89              156.651941                  0
#
#    order_app
# 0     7620.6
# 1     6505.2
# 2     7764.9
# 3     9254.7
# 4     9133.8

# %% [markdown]
# ## Разбиение на обучающую и тестовую выборку

# %%
# На всякий случай отсортируем по дате

data = data.sort_values("week")

# %%
data
# Out:
#           week  competitors_spendings  seasonality  fb_page_daily_viral_reach  \
# 0   2019-01-07           1.284923e+07     1.008971                       2219
# 1   2019-01-14           1.284923e+07     0.745846                       1841
# 2   2019-01-21           1.284923e+07     0.852687                       3103
# 3   2019-01-28           1.284923e+07     1.067596                       1838
# 4   2019-02-04           1.284923e+07     1.127907                       1541
# ..         ...                    ...          ...                        ...
# 100 2020-12-07           3.514336e+08     0.797074                       3923
# 101 2020-12-14           3.514336e+08     0.902144                       1336
# 102 2020-12-21           3.514336e+08     0.870342                       1826
# 103 2020-12-28           3.514336e+08     1.008971                       1780
# 104 2021-01-04           3.514336e+08     0.745846                       2162
#
#      holidays_  sms_resips    email  pandemia_search  vk_reach  price_ratio_  \
# 0          6.0         0.0        0              NaN      1965      1.499212
# 1          2.0         0.0        0              NaN      1772      1.576162
# 2          0.0         0.0        0              NaN      1862      1.578232
# 3          0.0         0.0        0              NaN     44102      1.579293
# 4          0.0         0.0        0              NaN     93440      1.552700
# ..         ...         ...      ...              ...       ...           ...
# 100        NaN     98730.0   559023        2552612.0   5817091      1.562042
# 101        NaN    159604.0  2619532        2496734.0    577940      1.527899
# 102        NaN    226907.0  1899226        2421822.0   6111738      1.568095
# 103        NaN    171201.0  2075833        2415153.0   7872782      1.603931
# 104        1.0    126343.0  2538875        1848973.0   1781939      1.603773
#
#      pr_coverage  app_clicks            ots  fb_page_daily_paid_reach  push  \
# 0            NaN        1098            NaN                  484530.0   0.0
# 1            NaN        2025            NaN                  523417.0   0.0
# 2            NaN        2921            NaN                   28250.0   0.0
# 3            NaN       19691            NaN                  238273.0   0.0
# 4            NaN       10472            NaN                  101968.0   0.0
# ..           ...         ...            ...                       ...   ...
# 100   63500000.0     8562870   51862.150460                40756625.0   NaN
# 101    3500000.0    14549709   72230.423541                37680056.0   NaN
# 102   26700000.0     6978942   72121.630550                26435790.0   NaN
# 103   19300000.0     6492044   60532.099207                16353591.0   NaN
# 104   17600000.0     6263336  106632.844238                12044577.0   NaN
#
#      price_index_macroeconomics  price_index_sbermarket  rebranding_contin  \
# 0                        101.36              151.960146                  0
# 1                        101.36              159.759803                  0
# 2                        101.36              159.969601                  0
# 3                        101.36              160.077088                  0
# 4                        100.89              156.651941                  0
# ..                          ...                     ...                ...
# 100                      101.71              158.875299                  1
# 101                      101.71              155.402615                  1
# 102                      101.71              159.490980                  1
# 103                      101.71              163.135796                  1
# 104                      101.72              163.135797                  1
#
#          order_app
# 0      7620.600000
# 1      6505.200000
# 2      7764.900000
# 3      9254.700000
# 4      9133.800000
# ..             ...
# 100  665185.348386
# 101  652379.497127
# 102  712776.256924
# 103  859594.393573
# 104  828778.855772
#
# [105 rows x 19 columns]

# %% [markdown]
# Оставим последние 10 недель на тест

# %%
train = data[:-10]

# %%
test = data[-10:]

# %%
print(f"Размер обучающей выборки: {len(train)}")
print(f"Размер тестовой выборки: {len(test)}")
# Out:
# Размер обучающей выборки: 95
# Размер тестовой выборки: 10

# %% [markdown]
# ## Подготовка данных для построения модели

# %% [markdown]
# ## Нормализация
#
# Изучите документацию [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) и [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html). Какой лучше использовать и для каких колонок? Внимание! Калибровать (`scaler.fit`) скейлеры нужно ТОЛЬКО на обучающей выборке. Примените скейлеры для ваших данных.

# %% [markdown]
# ## Замена пропусков
#
# В данных присутствуют пропуски. Их необходимо заполнить какими-то числами. В `pandas` это можно легко сделать при помощи `fillna` - почитайте о нем [тут](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html). Какие колонки как лучше заполнять? На данные в одной колонке полезно смотреть при помощи гистограммы. Построить ее легко можно при помощи:

# %%
train["order_app"].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Если вы хотите взять только строки за определенный период времени, то это можно сделать так:

# %%
from datetime import datetime

# %%
start_date = datetime(2019, 3, 1)  # 1 февраля 2019 года
end_date = datetime(2019, 5, 4)  # 4 апреля 2019 года

# %%
train[(train["week"] > start_date) & (train["week"] < end_date)]
# Out:
#          week  competitors_spendings  seasonality  fb_page_daily_viral_reach  \
# 8  2019-03-04             20353327.5     1.047454                       6138
# 9  2019-03-11             19955847.5     1.127784                       1439
# 10 2019-03-18             19955847.5     1.087044                       2353
# 11 2019-03-25             19955847.5     1.236907                       1218
# 12 2019-04-01             19955847.5     1.165207                       3037
# 13 2019-04-08             16595278.0     1.295782                       2048
# 14 2019-04-15             16595278.0     1.313502                       1732
# 15 2019-04-22             16595278.0     1.121689                        738
# 16 2019-04-29             16595278.0     1.147554                       1034
#
#     holidays_  sms_resips  email  pandemia_search  vk_reach  price_ratio_  \
# 8         0.0         0.0      0              NaN     35936      1.545915
# 9         1.0         0.0      0              NaN    100804      1.642271
# 10        0.0         0.0      0              NaN     16991      1.754682
# 11        0.0         0.0      0              NaN      8001      1.695400
# 12        0.0         0.0      0              NaN      3086      1.668538
# 13        0.0         0.0      0              NaN     77956      1.651961
# 14        0.0         0.0  42900              NaN      4495      1.583988
# 15        0.0         0.0   4468              NaN    170778      1.708024
# 16        0.0         0.0   5837              NaN      7557      2.004483
#
#     pr_coverage  app_clicks  ots  fb_page_daily_paid_reach  push  \
# 8           NaN       14045  NaN                  154816.0   0.0
# 9           NaN       23314  NaN                  335833.0   0.0
# 10          NaN       14744  NaN                  127923.0   0.0
# 11          NaN       13642  NaN                  181261.0   0.0
# 12          NaN      232597  NaN                   52261.0   0.0
# 13          NaN       29568  NaN                  308616.0   0.0
# 14          NaN       52597  NaN                  120277.0   0.0
# 15          NaN       60759  NaN                   84103.0   0.0
# 16          NaN       21966  NaN                   48652.0   0.0
#
#     price_index_macroeconomics  price_index_sbermarket  rebranding_contin  \
# 8                       100.57              155.472650                  0
# 9                       100.57              165.163244                  0
# 10                      100.57              176.468335                  0
# 11                      100.57              170.506412                  0
# 12                      100.57              167.804844                  0
# 13                      100.46              165.955978                  0
# 14                      100.46              159.127421                  0
# 15                      100.46              171.588095                  0
# 16                      100.46              201.370313                  0
#
#        order_app
# 8    6532.685121
# 9   11388.915388
# 10  11411.573519
# 11  13279.810752
# 12  11967.377362
# 13  14521.815153
# 14  15676.741330
# 15  12242.188702
# 16   9442.162193

# %% [markdown]
# Возможно, какие-то признаки имеют разное распределение в разные промежутки времени? Как можно лучше всего произвести замену пропусков для таких признаков? Пример замены пропусков на среднее значение:

# %%
train["holidays_"] = train["holidays_"].fillna(train["holidays_"].mean())
# Out:
# <ipython-input-15-4d22ad70210f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["holidays_"] = train["holidays_"].fillna(train["holidays_"].mean())

# %% [markdown]
# В рамках бейслайна просто заменим все пропуски на нули:

# %%
train = train.fillna(0)
test = test.fillna(0)

# %% [markdown]
# # Обучение модели

# %% [markdown]
# Обучите модель на обучающей выборке:

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X_train = train.drop(columns=["week", "order_app"])  # в признаки идут все данные, кроме этих колонок
y_train = train["order_app"]  # целевая переменная

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Получим предсказания модели на тестовой выборке:

# %%
X_test = test.drop(columns=["week", "order_app"])
y_true = test["order_app"]

y_pred = model.predict(X_test)

# %% [markdown]
# Рассчитаем метрику качества [MSE](https://en.wikipedia.org/wiki/Mean_squared_error):

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 49222605620.111435

# %% [markdown]
# 🤮

# %% [markdown]
# Посмотрим глазами на реальные значения и предсказания:

# %%
y_true.values
# Out:
# array([489398.3883126, 522536.9124573, 630737.7672453, 630104.5026276,
#        689511.0483417, 665185.348386 , 652379.4971265, 712776.2569239,
#        859594.3935735, 828778.8557724])

# %%
y_pred
# Out:
# array([549747.11374854, 480175.82387464, 550460.21758125, 530041.81115649,
#        467501.49851401, 470037.2960932 , 544374.91832185, 475260.21452222,
#        472921.12164283, 422126.03417381])

# %% [markdown]
# Такого простого подхода явно недостаточно!
